# %%
#importing libraries
from scipy.io import loadmat
import numpy as np
import math
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from mpl_toolkits.mplot3d import Axes3D
import os
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
cd ../DataForAlexandre/
# Out:
# /homecentral/alexandre.mahrach/gdrive/postdoc_IDIBAPS/DataForAlexandre

# %%
ls
# Out:
# C57_2_DualTask/  ChRM04/  JawsM15/

# %%
#specify the session of the experiment
folder = 'ChRM04'
session = '20200120'

# %%
#this is the fluorescence data
X_data = loadmat(session + '-C57-2-DualTaskAcrossDaySameROITrace' + '.mat')
#labels for the experiment (match with data)
y_data_labels = loadmat(session + '-C57-2-DualTask-SumFluoTraceFile' + '.mat')
#y_data_labels = loadmat('test.mat')

# %%
X_data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'SameAllCdf', 'SamedFF0'])

# %%
X_frame = np.rollaxis(X_data['SameAllCdf'],2,0)
X_frame_dF = np.rollaxis(X_data['SamedFF0'],2,0)

# %%
print('X_frame.shape')
print(X_frame.shape)
print('#trials, #neuron, #frames (time)')
# Out:
# X_frame.shape
# (240, 168, 143)
# #trials, #neuron, #frames (time)

# %%
print('Frame data has nan?')
print(np.isnan(X_frame).any())
print(np.isnan(X_frame_dF).any())
# Out:
# Frame data has nan?
# False
# False

# %%
# mean fluo F0 
t_baseline = 15
X_frame_F0 = np.mean(X_frame[:,:,0:t_baseline],axis=2) 
X_frame_F0[:,:,np.newaxis].shape
# Out:
# (240, 168, 1)

# %%
X_frame_dff0 = X_frame - X_frame_F0[:,:,np.newaxis]

# %%
def bin_data(X_window, bin_size, bin_overlap):
    for i in range(0,int(X_window.shape[2]/bin_size)):
        X_bin = np.concatenate[X_bin, np.mean(X_window[:,:,i:i+bin_size],axis=2)]
    return X_bin

# %%
X_frame_dff0 = np.delete(X_frame_dff0,np.s_[135:143],axis=2)

# %%
X_frame_dff0.shape
# Out:
# (240, 168, 135)

# %%
print(np.mean(np.take(X_frame_dff0,np.arange(0,10),axis=2),axis=2).shape)
print(np.mean(X_frame_dff0[:,:,0:10],axis=2).shape)
# Out:
# (240, 168)
# (240, 168)

# %%
def binArray(data, axis, binstep, binsize):
    out = [np.mean(np.take(data,np.arange(int(i*binstep),int(i*binstep+binsize)), axis=2), axis=2) for i in np.arange(data.shape[2]//binstep)-1]
    out = np.array(out)
    out = np.rollaxis(out,0,3)
    return out

# %%
X_avg = binArray(X_frame_dff0,2,10/2,10)

# %%
split_windows = np.array_split(X_frame_dff0, X_frame_dff0.shape[1]/50*7.5, axis=2)
#what has been created?
print('split_windows info')
print(type(split_windows))
print('length ' + str(len(split_windows)))
#iterate over the first five element
for i, window in enumerate(split_windows):
    print('element #' + str(i) )
    print(window.shape)

# %%
X_frame_dff0.shape
# Out:
# (240, 168, 143)

# %%
print('Frame data has nan?')
print( np.isnan(X_frame_F0).any() )
print( (X_frame_F0==0).any() )
# Out:
# Frame data has nan?
# False
# True

# %%
plt.plot(X_avg[0][1])

# %%
plt.plot(X_frame_dF[0][0])

# %%
y_data_labels.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'AllFileEvents20200120'])

# %%
y_frame_labels = y_data_labels['AllFileEvents'+session][0][0][0].transpose()

# %%
print('y_frame_labels.shape')
print(y_frame_labels.shape)
print('#labels, #trials')
print(np.unique(y_frame_labels, return_counts=True))
# Out:
# y_frame_labels.shape
# (9, 240)
# #labels, #trials
# (array([ 0,  1,  2,  3,  4, 11, 12, 13, 14, 15, 17, 18], dtype=int32), array([440, 439, 161,  68, 252, 120, 120,  80,  80, 160, 120, 120]))

# %%
print(y_frame_labels[1].shape)
print(np.unique(y_frame_labels, return_counts=True))
# Out:
# (240,)
# (array([ 0,  1,  2,  3,  4, 11, 12, 13, 14, 15, 17, 18], dtype=int32), array([440, 439, 161,  68, 252, 120, 120,  80,  80, 160, 120, 120]))

# %%
#ND_trials
y_ND_trials = np.argwhere((y_frame_labels[4]==0) & (y_frame_labels[8]==0)).flatten()
print(y_ND_trials.shape)
print(y_ND_trials)

#D1_trials
y_D1_trials = np.argwhere((y_frame_labels[4]==13) & (y_frame_labels[8]==0)).flatten()
print(y_D1_trials.shape)
print(y_D1_trials)

#D2_trials
y_D2_trials = np.argwhere((y_frame_labels[4]==14) & (y_frame_labels[8]==0)).flatten()
print(y_D2_trials.shape)
print(y_D2_trials)
# Out:
# (40,)
# [  0   1   2   3  12  13  14  15  48  49  50  51  60  61  62  63  96  97
#   98  99 108 109 110 111 144 145 146 147 156 157 158 159 192 193 194 195
#  204 205 206 207]
# (40,)
# [  4   7   8  10  16  18  21  23  53  54  56  59  64  67  69  70 101 102
#  104 106 113 114 117 119 149 150 152 155 160 162 164 167 196 197 202 203
#  208 211 212 214]
# (40,)
# [  5   6   9  11  17  19  20  22  52  55  57  58  65  66  68  71 100 103
#  105 107 112 115 116 118 148 151 153 154 161 163 165 166 198 199 200 201
#  209 210 213 215]

# %%
y_S1_ND_trials = np.argwhere(y_frame_labels[0][y_ND_trials]==17).flatten()
print(y_S1_ND_trials.shape)
print(y_S1_ND_trials)
# Out:
# (20,)
# [ 0  1  5  6  8  9 12 15 18 19 20 22 24 26 28 31 32 34 37 39]

# %%
y_S2_ND_trials = np.argwhere(y_frame_labels[0][y_ND_trials]==18).flatten()
print(y_S2_ND_trials.shape)
print(y_S2_ND_trials)
# Out:
# (20,)
# [ 2  3  4  7 10 11 13 14 16 17 21 23 25 27 29 30 33 35 36 38]

# %%
y_paired_ND_trials = np.argwhere( ((y_frame_labels[0][y_ND_trials]==17) & (y_frame_labels[1][y_ND_trials]==11)) | 
                                 ((y_frame_labels[0][y_ND_trials]==18) & (y_frame_labels[1][y_ND_trials]==12)) ).flatten() 
print(y_paired_ND_trials.shape)
print(y_paired_ND_trials)
# Out:
# (20,)
# [ 1  3  6  7  8 11 12 14 16 18 22 23 25 26 30 31 32 35 37 38]

# %%
y_non_paired_ND_trials = np.argwhere( ((y_frame_labels[0][y_ND_trials]==17) & (y_frame_labels[1][y_ND_trials]==12)) | 
                                 ((y_frame_labels[0][y_ND_trials]==18) & (y_frame_labels[1][y_ND_trials]==11)) ).flatten() 
print(y_non_paired_ND_trials.shape)
print(y_non_paired_ND_trials)
# Out:
# (20,)
# [ 0  2  4  5  9 10 13 15 17 19 20 21 24 27 28 29 33 34 36 39]

# %%
# ND trials
X_ND_trials = X_avg[y_ND_trials]
X_ND_trials.shape

X_S1_ND_trials = X_frame_dff0[y_S1_ND_trials]
X_S2_ND_trials = X_frame_dff0[y_S2_ND_trials]

X_paired_ND_trials = X_frame_dff0[y_paired_ND_trials]
X_non_paired_ND_trials = X_frame_dff0[y_non_paired_ND_trials]

# %%
X_D1_trials = X_frame_dff0[y_D1_trials]
X_D1_trials.shape

X_D2_trials = X_frame_dff0[y_D2_trials]
X_D2_trials.shape
# Out:
# (40, 168, 143)

# %%
# average over trials as in Panichello
X_ND_avg = np.mean(X_ND_trials,axis=0) 
X_ND_avg.shape

# X_S1_ND_avg = np.mean(X_S1_ND_trials,axis=0)
# X_S2_ND_avg = np.mean(X_S2_ND_trials,axis=0)

# X_paired_ND_avg = np.mean(X_paired_ND_trials,axis=0) 
# X_paired_ND_avg.shape

# X_non_paired_ND_avg = np.mean(X_non_paired_ND_trials,axis=0) 
# X_non_paired_ND_avg.shape

# X_D1_avg = np.mean(X_D1_trials,axis=0) 
# X_D1_avg.shape

# X_D2_avg = np.mean(X_D2_trials,axis=0) 
# X_D2_avg.shape
# Out:
# (168, 27)

# %%
143/7.5
# Out:
# 19.066666666666666

# %%
time = np.linspace(0,20,143);
X_Window = X_S1_ND_avg
X_avg = np.mean(X_Window,axis=0)
X_std = np.std(X_Window,axis=0)

plt.plot(time,X_avg,c='k')
plt.fill_between(time, X_avg - X_std, X_avg + X_std, alpha=0.25, color='magenta')

plt.axvline(x=2, c='black')
plt.axvline(x=3, c='black')

plt.axvline(x=13, c='black')
plt.axvline(x=14, c='black')

plt.xlabel('frame') ;
plt.ylabel('$\Delta F$') ;

# %%
t_window = 15
t_delay_1 = 38
t_delay_2 = 143-t_window

# %%
X_Delay_1_ND_trials = X_ND_trials[:,:,t_delay_1:t_delay_1+t_window]
X_Delay_2_ND_trials = X_ND_trials[:,:,t_delay_2:t_delay_2+t_window]

X_Delay_1_D1_trials = X_D1_trials[:,:,t_delay_1:t_delay_1+t_window]
X_Delay_2_D1_trials = X_D1_trials[:,:,t_delay_2:t_delay_2+t_window]

X_Delay_1_D2_trials = X_D2_trials[:,:,t_delay_1:t_delay_1+t_window]
X_Delay_2_D2_trials = X_D2_trials[:,:,t_delay_2:t_delay_2+t_window]

# %%
X_Delay_1_ND_avg = X_ND_avg[:,t_delay_1:t_delay_1+t_window]
X_Delay_2_ND_avg = X_ND_avg[:,t_delay_2:t_delay_2+t_window]

X_Delay_1_D1_avg = X_D1_avg[:,t_delay_1:t_delay_1+t_window]
X_Delay_2_D1_avg = X_D1_avg[:,t_delay_2:t_delay_2+t_window]

X_Delay_1_D2_avg = X_D2_avg[:,t_delay_1:t_delay_1+t_window]
X_Delay_2_D2_avg = X_D2_avg[:,t_delay_2:t_delay_2+t_window]

# %%
X_all_trials_avg = np.concatenate([X_S1_ND_avg, X_S2_ND_avg])
print(X_all_trials_avg.shape)
X_all_avg_cond = np.mean(X_all_trials_avg,axis=0)

X_all_trials_avg_norm = X_all_trials_avg- X_all_avg_cond[np.newaxis,:]
# Out:
# (336, 143)

# %%
def pca_func(X_Window,n_pca):
    # reshaping the array for samples = trials features = neurons by time features
    # X_Window  = np.reshape((X_Window), (X_Window.shape[0], X_Window.shape[1]* X_Window.shape[2]))
    #Standardizing the features
    X_Window = StandardScaler().fit_transform(X_Window)  
    # PCA projection to 2D
    pca = PCA(n_components=n_pca)
    principal_components = pca.fit_transform(X_Window)
    principal_components = principal_components.transpose()
    explained_variance = pca.explained_variance_ratio_
    return principal_components, explained_variance

# %%
def pca_trajectory(X_trials,time_window,n_pca):
    # split_windows = np.array_split(X_trials, X_trials.shape[1]/time_window, axis=1)
    i=0
    # for X_window in split_windows:
    for j in np.arange(X_trials.shape[0]):
        principal_components, explained_variance = pca_func(X_trials[j],n_pca)
        # mean_pc = np.mean(principal_components,axis=1)
        if i==0:
          pc_vec = mean_pc[:,np.newaxis]
          i=i+1
        else:
          pc_vec = np.concatenate([pc_vec, mean_pc[:,np.newaxis]],axis=1)
    return pc_vec

# %%
X_ND_avg.transpose().shape
pca_plot(X_ND_avg, X_ND_avg, 2)
# Out:
# [0.4660848  0.29131584] [0.4660848  0.29131584]

# %%
pca_trajectory(X_ND_avg.transpose(),1,2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-193-8dd0364e6dd7> in <module>()
# ----> 1 pca_trajectory(X_ND_avg.transpose(),1,2)
#
# <ipython-input-189-654abfb0d8b6> in pca_trajectory(X_trials, time_window, n_pca)
#       4     # for X_window in split_windows:
#       5     for j in np.arange(X_trials.shape[0]):
# ----> 6         principal_components, explained_variance = pca_func(X_trials[j],n_pca)
#       7         mean_pc = np.mean(principal_components,axis=1)
#       8         if i==0:
#
# <ipython-input-158-b501880dcd34> in pca_func(X_Window, n_pca)
#       3     # X_Window  = np.reshape((X_Window), (X_Window.shape[0], X_Window.shape[1]* X_Window.shape[2]))
#       4     #Standardizing the features
# ----> 5     X_Window = StandardScaler().fit_transform(X_Window)
#       6     # PCA projection to 2D
#       7     pca = PCA(n_components=n_pca)
#
# ...

# %%
pca_trajectory(X_ND_avg,50/7.5,3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-175-c691364c1548> in <module>()
# ----> 1 pca_trajectory(X_ND_avg,50/7.5,3)
#
# <ipython-input-173-6a4dd0028c86> in pca_trajectory(X_trials, time_window, n_pca)
#       4     # for X_window in split_windows:
#       5     for j in np.arange(X_trials.shape[0]):
# ----> 6         principal_components, explained_variance = pca_func(X_trials[j],n_pca)
#       7     #     mean_pc = np.mean(principal_components,axis=1)
#       8     #     if i==0:
#
# <ipython-input-158-b501880dcd34> in pca_func(X_Window, n_pca)
#       3     # X_Window  = np.reshape((X_Window), (X_Window.shape[0], X_Window.shape[1]* X_Window.shape[2]))
#       4     #Standardizing the features
# ----> 5     X_Window = StandardScaler().fit_transform(X_Window)
#       6     # PCA projection to 2D
#       7     pca = PCA(n_components=n_pca)
#
# ...

# %%
a,b = pca_func(X_ND_avg,3)
print(a.shape)
b = np.mean(a,axis=1)
print(b.shape)
c = np.concatenate([b[:,np.newaxis],b[:,np.newaxis]],axis=1)
print(c.shape)
c = np.concatenate([c,b[:,np.newaxis]],axis=1)
print(c.shape)
# Out:
# (3, 168)
# (3,)
# (3, 2)
# (3, 3)

# %%
fig = plt.figure(1, figsize=(4, 3))
plt.clf()
ax = Axes3D(fig, rect=[0, 0, 1, 1], azim=60, elev=15)
ax.plot(a[0],a[1],a[2], c='k')

# %%
time_window = 50/7.5
split_windows = np.array_split(X_ND_avg, X_ND_avg.shape[1]/time_window, axis=1)
# #what has been created?
# print('split_windows info')
# print(type(split_windows))
# print('length ' + str(len(split_windows)))
# #iterate over the first five element
# for i, window in enumerate(split_windows):
#     print('element #' + str(i) )
#     print(window.shape)

# %%
a,b = pca_func(X_all_trials_avg_norm,3);
print(a.shape)
b = np.empty()
print(b.shape)
c = np.concatenate([b,a])
print(c.shape)
# Out:
# (3, 336)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-c596ab25219e> in <module>()
#       1 a,b = pca_func(X_all_trials_avg_norm,3);
#       2 print(a.shape)
# ----> 3 b = np.empty()
#       4 print(b.shape)
#       5 c = np.concatenate([b,a])
#
# TypeError: Required argument 'shape' (pos 1) not found

# %%
def pca_2D(pca_delay_1_trials, pca_delay_2_trials):
    fig = plt.figure(figsize = (8,8))
    ax = fig.add_subplot(1,1,1) 
    ax.set_xlabel('Principal Component 1', fontsize = 15)
    ax.set_ylabel('Principal Component 2', fontsize = 15)
    ax.set_title('2 component PCA', fontsize = 20)
    ax.scatter(pca_delay_1_trials[0],pca_delay_1_trials[1],c='b')
    ax.scatter(pca_delay_2_trials[0],pca_delay_2_trials[1],c='r')

# %%
def pca_3D(pca_delay_1_trials, pca_delay_2_trials):
    fig = plt.figure(1, figsize=(4, 3))
    plt.clf()
    ax = Axes3D(fig, rect=[0, 0, 1, 1])
    ax.scatter(pca_delay_1_trials[0], pca_delay_1_trials[1], pca_delay_1_trials[2], c='b')
    ax.scatter(pca_delay_2_trials[0], pca_delay_2_trials[1], pca_delay_1_trials[2], c='r')

# %%
def pca_plot(X_Delay_1_trials, X_Delay_2_trials, n_pca):
    pca_delay_1_trials = pca_func(X_Delay_1_trials,n_pca)
    pca_delay_2_trials = pca_func(X_Delay_2_trials,n_pca)

    print(pca_delay_1_trials[1],pca_delay_2_trials[1])
    if n_pca==2:
      pca_2D(pca_delay_1_trials[0],pca_delay_2_trials[0])
    else:
      pca_3D(pca_delay_1_trials[0],pca_delay_2_trials[0])

# %%
pca_plot(X_all_trials_avg_norm[:,t_delay_1:t_delay_1+t_window], X_all_trials_avg_norm[:,t_delay_2:t_delay_2+t_window], 2)
# Out:
# [0.90029367 0.06327749] [0.88978467 0.06615805]

# %%
pca_plot(X_Delay_1_ND_avg, X_Delay_2_ND_avg, 2)
# Out:
# [0.97393658 0.01354768] [0.92359886 0.04654169]

# %%
pca_plot(X_Delay_1_D1_avg, X_Delay_2_D1_avg, 2)
# Out:
# [0.93433242 0.04424373] [0.9650426  0.02124249]

# %%
pca_plot(X_Delay_1_D2_avg, X_Delay_2_D2_avg, 2)
# Out:
# [0.96146523 0.02491863] [0.9551012  0.02184945]

# %%
pca_plot(X_Delay_1_ND_avg, X_Delay_2_ND_avg, 3)
# Out:
# [0.97393658 0.01354768 0.00339314] [0.92359886 0.04654169 0.00813199]

# %%
pca_plot(X_Delay_1_D1_avg, X_Delay_2_D1_avg, 3)
# Out:
# [0.93433242 0.04424373 0.00801465] [0.9650426  0.02124249 0.00408073]

# %%
pca_plot(X_Delay_1_D2_avg, X_Delay_2_D2_avg, 3)
# Out:
# [0.96146523 0.02491863 0.00406421] [0.9551012  0.02184945 0.00676921]
